# %% [markdown]
#  Machine Learning.
#
# ### Non-Linear Regression
#
# # Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/china_gdp.csv"
   
df = pd.read_csv(url)
df.head(10)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (df["Year"].values, df["Value"].values)
plt.plot(x_data, y_data, 'ro')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ## Ma'lumotlarni ajratib olamiz va Normalizasiya qilamiz

# %%
X = np.asanyarray((df[["Year"]])/df.Year.max())
y = np.asanyarray(df[['Value']]/df.Value.max())

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
yhat = model.predict(X)

# %%
plt.figure(figsize=(10,6))
plt.plot(X, y, "ro", label="data")
plt.plot(X, yhat, linewidth=3.0, label="fit")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

print("MAE:", mean_absolute_error(yhat,y))
# Out:
# MAE: 0.12657979406214762

# %% [markdown]
# ### Polynominal Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=5, include_bias=False)
X_poly = poly_features.fit_transform(X)

# %%
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
yhat = model.predict(X_poly)

# %%
plt.figure(figsize=(10,6))
plt.plot(X, y, 'ro', label='data')
plt.plot(X,yhat, linewidth=4.0, label='fit')
plt.show()

# %%
print(f"MAE={mean_absolute_error(yhat, y)}")
# Out:
# MAE=0.009254054119989636

# %% [markdown]
# ### `curve_fit`
# 'curve_fit' yordamida o'zimiz yozgan funksiyalar asosida model qurishimiz mumkin.
#
# Misol uchun, yuqoridagi ma'lumotlar Logistic regression funksiyasi yordamida aniqroq bashorat qilinishi mumkin.
#
# # $$ \hat{Y} = \frac1{1+e^{-\beta_1(X-\beta_2)}}$$
#
# Keling, logisti regression funksiyasini yozib olamiz:

# %%
x_data, y_data = (df["Year"].values, df["Value"].values)
xdata =x_data/max(x_data)
ydata =y_data/max(y_data)

# %%
def sigmoid(x, Beta_1, Beta_2):
     y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
     return y

# %%
from scipy.optimize import curve_fit

beta, pcov = curve_fit(sigmoid, xdata, y_data)
print(f"Beta2-{beta[0]}\nBeta2-{beta[1]}")
# Out:
# Beta2-1.0
# Beta2-1.0
# /tmp/ipykernel_7618/3388949757.py:3: OptimizeWarning: Covariance of the parameters could not be estimated
#   beta, pcov = curve_fit(sigmoid, xdata, y_data)

# %%
from scipy.optimize import curve_fit

beta, pcov = curve_fit(sigmoid, xdata, ydata)
print(f"beta1={beta[0]}\nbeta2={beta[1]}")
# Out:
# beta1=690.4517083847173
# beta2=0.9972071272536834

# %%
x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
yhat = sigmoid(x, *beta)
plt.plot(xdata, ydata, "ro", label="data")
plt.plot(x,yhat, linewidth=3.0, label="fit")
plt.legend(loc="best")
plt.ylabel("GDP")
plt.xlabel("Year")
plt.show()
